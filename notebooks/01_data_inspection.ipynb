# %% [markdown]
# # 01 — Data inspection
#
# Run this notebook only after placing the supplied files in `data/raw/`. It does not assume CSV columns or target units.

# %%
from pathlib import Path
import subprocess, sys
root = Path('..').resolve()
subprocess.run([sys.executable, 'scripts/inspect_data.py'], cwd=root, check=True)

# %%
import json
summary = json.loads((root / 'outputs' / 'data_summary.json').read_text())
summary

# %% [markdown]
# ## Review before modeling
# Confirm the target column, A/B pair identifier columns, identifier-to-XYZ-frame mapping, units, and whether reverse pairs exist. Then update YAML configs; do not infer these details from file names.
