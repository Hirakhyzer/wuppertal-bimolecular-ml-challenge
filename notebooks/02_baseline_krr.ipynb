# %% [markdown]
# # 02 — Baseline Kernel Ridge Regression
#
# This notebook is intentionally a guided scaffold. Complete the CSV-to-XYZ-frame mapping only after reviewing `outputs/data_summary.json`.

# %%
from pathlib import Path
import sys
root = Path('..').resolve()
sys.path.insert(0, str(root))
from src.config import load_yaml_config, require_confirmed_schema
config = load_yaml_config(root / 'configs' / 'baseline_krr.yaml')
require_confirmed_schema(config)

# %% [markdown]
# ## Next implementation step
# Use the confirmed identifier mapping to assemble aligned A/B geometry features, choose one documented split, fit the KRR validation grid, and save only locally generated result records.
