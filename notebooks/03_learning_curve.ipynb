# %% [markdown]
# # 03 — Learning curve
#
# The learning curve must be generated from executed experiments only. It uses a double-logarithmic plot of training pair count versus validation MAE.

# %%
from pathlib import Path
import sys
root = Path('..').resolve()
sys.path.insert(0, str(root))
from src.learning_curve import feasible_log_sizes
feasible_log_sizes([100, 250, 500, 1000, 2000, 4000], available_train_samples=4000, max_krr_train_samples=4000)

# %% [markdown]
# ## Required before execution
# Confirm schema and A/B frame mapping, select a leakage-aware split, and use validation-only hyperparameter selection. Then write the CSV and figure paths declared in `configs/learning_curve.yaml`.
